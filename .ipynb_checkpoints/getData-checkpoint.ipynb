# %%
# Import the yfinance. If you get module not found error the run !pip install yfianance from your Jupyter notebook
import yfinance as yf

# Get the data for the stock AAPL
data = yf.download('AAPL','2016-01-01','2019-08-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
data['Adj Close'].plot()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
# Define the ticker list
import pandas as pd

ticker = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Import pandas
data = pd.DataFrame(columns=tickers_list)

# %%
data= yf.download(ticker,'2016-01-01','2019-08-01')['Adj Close']
# Out:
# [*********************100%***********************]  6 of 6 downloaded

# %%
data.head()
# Out:
#              AAPL    AXP      BA     IBM     MU    WMT
# Date
# 2015-12-31  98.13  65.00  129.44  114.21  14.16  55.60
# 2016-01-04  98.21  63.17  125.78  112.82  14.33  55.74
# 2016-01-05  95.75  62.19  126.29  112.74  14.82  57.07
# 2016-01-06  93.88  60.47  124.29  112.17  14.22  57.64
# 2016-01-07  89.92  59.92  119.08  110.26  13.66  58.98

# %%
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Adjusted Close Price", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
# Uncomment below line to install alpha_vantage
#!pip install alpha_vantage
# Import the library
from alpha_vantage.timeseries import TimeSeries

# initialize TS object with API key and output format
ts = TimeSeries(key='Your-API-Key', output_format='pandas')

# Get the data
data, meta_data = ts.get_intraday(symbol='AAPL',interval='5min', outputsize='compact')

# Print the data
print(data.head())
# Out:
#                       1. open   2. high   3. low  4. close  5. volume
# date
# 2020-02-06 14:15:00  324.9500  324.9700  324.867  324.9400   149529.0
# 2020-02-06 14:20:00  324.9495  324.9600  324.420  324.4200   263252.0
# 2020-02-06 14:25:00  324.4517  324.8115  324.301  324.5217   378346.0
# 2020-02-06 14:30:00  324.5100  324.6920  324.478  324.6150   283464.0
# 2020-02-06 14:35:00  324.6332  324.9200  324.580  324.9000   213978.0

# %%
data.tail()
# Out:
#                      1. open  2. high   3. low  4. close  5. volume
# date
# 2020-02-07 15:40:00  319.280  319.280  319.013  319.0300   303797.0
# 2020-02-07 15:45:00  319.030  319.880  318.970  319.6281   522083.0
# 2020-02-07 15:50:00  319.635  319.710  319.570  319.6500   396199.0
# 2020-02-07 15:55:00  319.680  319.766  319.530  319.7659   635620.0
# 2020-02-07 16:00:00  319.750  320.080  319.690  320.0400  1031691.0
